# %% [markdown]
# # Importing Python libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import datetime
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\Akshat\.jupyter\Desktop\Work place\python data set\1. Weather Data.csv')

# %% [markdown]
# # Shows the First 3 Rows of dataset.

# %%
data.head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %% [markdown]
# # Basic information about the Data: Rows,columns,Types.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# # Types of Rows

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# # Q1 . Show the first five Rows in the data.

# %%
data[:5]  #OR data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# # Q2 Find out different Weather Conditions.

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# # Checking Null Values

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# # Shown Null Values through heatmap

# %%
sns.heatmap(data.isnull(),yticklabels = False, cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Find number of times weather is exactly Clear

# %%
data[(data.Weather=='Clear')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data[(data.Weather=='Clear')].value_counts()
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/11/2012 1:00   -10.7   -17.8             56         17               25.0           101.49     Clear      1
# 6/14/2012 3:00    12.3    5.3              62         13               25.0           101.96     Clear      1
# 6/14/2012 23:00   19.6    5.8              40         6                25.0           102.21     Clear      1
# 6/14/2012 22:00   20.2    6.0              39         9                25.0           102.20     Clear      1
# 6/14/2012 21:00   21.0    6.0              38         11               25.0           102.16     Clear      1
#                                                                                                            ..
# 2/4/2012 19:00   -7.7    -14.0             61         7                25.0           101.97     Clear      1
# ...

# %% [markdown]
# # All Unique wind speed in Dataset

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# # Number of times Wind speed was exactly 7.

# %%
data[(data['Wind Speed_km/h']==7)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# 7        1/1/2012 7:00    -1.4              -3.6         85                7
# 11      1/1/2012 11:00    -0.5              -2.1         89                7
# ...                ...     ...               ...        ...              ...
# 8647   12/26/2012 7:00   -13.0             -14.4         89                7
# 8693   12/28/2012 5:00    -5.0              -6.1         92                7
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
# 8723  12/29/2012 11:00   -10.9             -12.2         90                7
#
# ...

# %%
data[(data['Wind Speed_km/h']==7)].count()
# Out:
# Date/Time           677
# Temp_C              677
# Dew Point Temp_C    677
# Rel Hum_%           677
# Wind Speed_km/h     677
# Visibility_km       677
# Press_kPa           677
# Weather             677
# dtype: int64

# %% [markdown]
# # Weather and Temprature columns from the dataset

# %%
data[['Weather','Temp_C']].head(7)
# Out:
#                 Weather  Temp_C
# 0                   Fog    -1.8
# 1                   Fog    -1.8
# 2  Freezing Drizzle,Fog    -1.8
# 3  Freezing Drizzle,Fog    -1.5
# 4                   Fog    -1.5
# 5                   Fog    -1.4
# 6                   Fog    -1.5

# %% [markdown]
# # Get first 20 rows from the dataset.

# %%
data[:20]  #OR  data[0:20] OR data.head(20)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 2    1/1/2012 2:00    -1.8              -3.4         89                7
# 3    1/1/2012 3:00    -1.5              -3.2         88                6
# 4    1/1/2012 4:00    -1.5              -3.3         88                7
# 5    1/1/2012 5:00    -1.4              -3.3         87                9
# 6    1/1/2012 6:00    -1.5              -3.1         89                7
# 7    1/1/2012 7:00    -1.4              -3.6         85                7
# 8    1/1/2012 8:00    -1.4              -3.6         85                9
# 9    1/1/2012 9:00    -1.3              -3.1         88               15
# 10  1/1/2012 10:00    -1.0              -2.3         91                9
# 11  1/1/2012 11:00    -0.5              -2.1         89                7
# ...

# %% [markdown]
# # Get First 5 Presssure values.

# %%
data['Press_kPa'].head(5)
# Out:
# 0    101.24
# 1    101.24
# 2    101.26
# 3    101.27
# 4    101.23
# Name: Press_kPa, dtype: float64

# %% [markdown]
# # Find all instances when  wind speed was above 30 and  Visibility was 25

# %%
data[(data['Wind Speed_km/h']> 30) & (data['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# 28       1/2/2012 4:00     2.9              -2.3         69               32
# ...                ...     ...               ...        ...              ...
# 8407   12/16/2012 7:00    -9.8             -14.9         66               32
# 8538  12/21/2012 18:00     1.4               0.3         92               46
# 8569   12/23/2012 1:00    -7.9             -11.8         74               32
# 8659  12/26/2012 19:00    -9.6             -13.1         76               39
# 8662  12/26/2012 22:00    -9.7             -12.8         78               37
#
# ...

# %% [markdown]
# # Top 10 hottest temp values and their counts.

# %%
data['Temp_C'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 16.6    65
# 1.1     58
# 0.8     47
# 1.5     45
# 19.3    44
# 21.1    43
# 2.6     43
# 0.4     41
# 1.3     40
# 14.6    39
# Name: Temp_C, dtype: int64

# %% [markdown]
# # Rename the Column Weather to Weather Condition.

# %%
data.rename(columns = {'Weather':'Weather conditions'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # Minimum and Maximum value of each column against each "Weather Condition".

# %%
data.groupby('Weather').min().head(15)
# Out:
#                                 Date/Time  Temp_C  Dew Point Temp_C  \
# Weather
# Clear                      1/11/2012 1:00   -23.3             -28.5
# Cloudy                     1/1/2012 17:00   -21.4             -26.8
# Drizzle                   1/23/2012 21:00     1.1              -0.2
# Drizzle,Fog               1/23/2012 20:00     0.0              -1.6
# Drizzle,Ice Pellets,Fog   12/17/2012 9:00     0.4              -0.7
# Drizzle,Snow             12/17/2012 15:00     0.9               0.1
# Drizzle,Snow,Fog         12/18/2012 21:00     0.3              -0.1
# Fog                         1/1/2012 0:00   -16.0             -17.2
# Freezing Drizzle          1/13/2012 10:00    -9.0             -12.2
# Freezing Drizzle,Fog        1/1/2012 2:00    -6.4              -9.0
# Freezing Drizzle,Haze      2/1/2012 11:00    -5.8              -8.3
# Freezing Drizzle,Snow      1/13/2012 3:00    -8.3             -10.4
# Freezing Fog               1/22/2012 6:00   -19.0             -22.9
# ...

# %%
data.groupby('Weather').max().head(15)
# Out:
#                                 Date/Time  Temp_C  Dew Point Temp_C  \
# Weather
# Clear                       9/9/2012 5:00    32.8              20.4
# Cloudy                     9/9/2012 23:00    30.5              22.6
# Drizzle                    9/30/2012 3:00    18.8              17.7
# Drizzle,Fog                9/30/2012 2:00    19.9              19.1
# Drizzle,Ice Pellets,Fog   12/17/2012 9:00     0.4              -0.7
# Drizzle,Snow             12/19/2012 18:00     1.2               0.2
# Drizzle,Snow,Fog          12/22/2012 3:00     1.1               0.6
# Fog                        9/22/2012 0:00    20.8              19.6
# Freezing Drizzle            2/1/2012 5:00    -2.3              -3.3
# Freezing Drizzle,Fog      12/10/2012 5:00    -0.3              -2.3
# Freezing Drizzle,Haze      2/1/2012 13:00    -5.0              -7.7
# Freezing Drizzle,Snow      3/2/2012 12:00    -3.3              -4.6
# Freezing Fog               3/17/2012 6:00    -0.1              -0.3
# ...

# %% [markdown]
# # Data Visualization

# %%
data['Weather'].value_counts().head(10)
# Out:
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Rain              306
# Rain Showers      188
# Fog               150
# Rain,Fog          116
# Drizzle,Fog        80
# Name: Weather, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(y ='Weather' ,order = data['Weather'].value_counts().index[0:15],data = data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Weather'>

# %%
fig=data['Visibility_km'].value_counts().plot.bar().get_figure()
fig.tight_layout()
